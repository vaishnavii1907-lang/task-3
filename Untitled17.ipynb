# %%
# ============================================================
# 📊 TASK 3: DATA VISUALIZATION (FULL LONG CODE)
# ============================================================

# -----------------------------
# 1️⃣ Import Libraries
# -----------------------------
# Out:
# ===== INSIGHTS FROM VISUALIZATION =====
# 1. Category A has the maximum number of students.
# 2. Category A students scored the highest average in Maths.
# 3. Maths marks increased towards later months.
# 4. Strong positive correlation between Maths and Physics.
# 5. Most students scored between 75–95 in Maths.
# 6. Physics has maximum variation; Chemistry is more stable.
# ...
